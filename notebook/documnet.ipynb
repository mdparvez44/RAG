# %% [markdown]
# Data Ingestion

# %%
from langchain_core.documents import Document

# %%
# create a simple text file
import os
os.makedirs("../data/text_files", exist_ok=True)

# %%
sample_texts={
    "../data/text_files/python_intro.txt":"""Python is a popular, high-level programming language released in 1991 by Guido van Rossum. It is celebrated for its simple, English-like syntax that emphasizes readability and allows developers to write programs with fewer lines of code than languages like C++ or Java. [1, 2, 3]  
Key Features 

• Interpreted Language: Python runs on an interpreter system, meaning code is executed line-by-line, which enables rapid prototyping. 
• Dynamically Typed: You do not need to declare variable types explicitly; the interpreter detects them at runtime. 
• Versatile Paradigms: It supports procedural, object-oriented, and functional programming styles. 
• Cross-Platform: Python works across Windows, Mac, Linux, and specialized hardware like Raspberry Pi. [1, 2, 3, 4]  

Common Applications 

• Web Development: Handling server-side logic and backend workflows. 
• Data Science & AI: Analyzing big data, performing complex mathematics, and building machine learning models. 
• Automation: Writing scripts to handle repetitive tasks or system administration. 
• Software Prototyping: Quickly creating "production-ready" software designs. [1, 2, 3, 5, 6]  

Core Concepts for Beginners 

1. Variables & Types: Storing data like numbers (integers, floats) and text (strings). 
2. Control Flow: Using  statements for decisions and  or  loops for repetitive tasks. 
3. Functions: Defining reusable blocks of code using the  keyword. 
4. Data Structures: Organizing information using lists, dictionaries, tuples, and sets. [7, 8, 9, 10, 11, 12]  

Getting Started Resources 

• Official Docs: Use the Python.org Getting Started guide for downloads and installation. 
• Interactive Tutorials: Try W3Schools Python Tutorial or LearnPython.org for hands-on practice. 
• Free Courses: Harvard’s  CS50P on edX 
 or Google’s Python Class offer structured paths. 
""",

"../data/text_files/ML_intro.txt":"""Machine learning (ML) is a subset of artificial intelligence (AI) that enables systems to learn from data, identify patterns, and make decisions or predictions without being explicitly programmed for every specific task. It focuses on developing algorithms that allow computers to improve their performance autonomously as they are exposed to more data. [1, 2, 3, 4]  
This video explains the core concepts of machine learning in 100 seconds: 
Key aspects of machine learning include: 

• How it Works: Instead of hard-coded rules, ML models are trained using large datasets to recognize patterns and make, or aid in, decisions. 
• Types of Learning: 

	• Supervised Learning: Algorithms learn from labeled data to predict outcomes (e.g., spam detection). 
	• Unsupervised Learning: Algorithms find hidden patterns or structures in unlabeled data (e.g., customer segmentation). 
	• Reinforcement Learning: Systems learn by trial and error to achieve a goal, receiving rewards for correct actions (e.g., autonomous driving). 
	• Generative AI: Models create new content (text, images) based on learned patterns. 

• Common Applications: Fraud detection, recommendation engines (like Netflix), image recognition, natural language processing, and predictive maintenance. 
• Key Techniques: Neural networks and deep learning are frequently used to handle complex tasks. [3, 5, 6, 7, 8, 9]  

This video provides an overview of the main types of machine learning: 
Machine learning is fundamental in shifting from rules-based programming to data-driven decision-making, allowing systems to enhance their accuracy over time. [4, 10]  
"""
    
}

for filepath, content in sample_texts.items():
    with open(filepath, 'w', encoding="utf-8") as f:
        f.write(content)

print("✅Smaple text files created!")
# Out:
# ✅Smaple text files created!

# %%
#TextLoader
from langchain_community.document_loaders import TextLoader

loader=TextLoader("../data/text_files/python_intro.txt",encoding="utf-8")

document=loader.load()
print(document)
# Out:
# [Document(metadata={'source': '../data/text_files/python_intro.txt'}, page_content='Python is a popular, high-level programming language released in 1991 by Guido van Rossum. It is celebrated for its simple, English-like syntax that emphasizes readability and allows developers to write programs with fewer lines of code than languages like C++ or Java. [1, 2, 3]  \nKey Features \n\n• Interpreted Language: Python runs on an interpreter system, meaning code is executed line-by-line, which enables rapid prototyping. \n• Dynamically Typed: You do not need to declare variable types explicitly; the interpreter detects them at runtime. \n• Versatile Paradigms: It supports procedural, object-oriented, and functional programming styles. \n• Cross-Platform: Python works across Windows, Mac, Linux, and specialized hardware like Raspberry Pi. [1, 2, 3, 4]  \n\nCommon Applications \n\n• Web Development: Handling server-side logic and backend workflows. \n• Data Science & AI: Analyzing big data, pe
# ...

# %%
#Directory Loader
from langchain_community.document_loaders import DirectoryLoader

dir = DirectoryLoader(
    "../data/text_files",
    glob="**/*.txt",
    loader_cls=TextLoader,
    loader_kwargs={'encoding':'utf-8'},
    show_progress=False
)

documnet=dir.load()
documnet
# Out:
# [Document(metadata={'source': '../data/text_files/ML_intro.txt'}, page_content='Machine learning (ML) is a subset of artificial intelligence (AI) that enables systems to learn from data, identify patterns, and make decisions or predictions without being explicitly programmed for every specific task. It focuses on developing algorithms that allow computers to improve their performance autonomously as they are exposed to more data. [1, 2, 3, 4]  \nThis video explains the core concepts of machine learning in 100 seconds: \nKey aspects of machine learning include: \n\n• How it Works: Instead of hard-coded rules, ML models are trained using large datasets to recognize patterns and make, or aid in, decisions. \n• Types of Learning: \n\n\t• Supervised Learning: Algorithms learn from labeled data to predict outcomes (e.g., spam detection). \n\t• Unsupervised Learning: Algorithms find hidden patterns or structures in unlabeled data (e.g., customer segmentation). \n\t• Reinforcement Learning: 
# ...

# %%
#PDFLoader
from langchain_community.document_loaders import PyPDFLoader, PyMuPDFLoader

pdf = DirectoryLoader(
    "../data/pdf",
    glob="**/*.pdf",
    loader_cls=PyMuPDFLoader,
    show_progress=True
)

pdf_doc=pdf.load()
pdf_doc
# Out:
# 100%|██████████| 3/3 [00:00<00:00, 12.47it/s]
# ...
